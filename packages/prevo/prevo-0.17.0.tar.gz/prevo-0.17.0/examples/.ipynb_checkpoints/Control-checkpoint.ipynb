# %%
from prevo.misc import DummyCirculatedBath
from prevo.control import PeriodicControl, Program, Stairs, Teeth
# %matplotlib inline

# %% [markdown]
# # Define Control Object

# %%
class BathControl(PeriodicControl):
    """Dummy control object"""
    
    # Allowed inputs as parameters for control (e.g., vapor pressure, %RH etc)
    # (optional, only for checking entries)
    possible_inputs = 'T', 'K'
    
    def __init__(self, bath, dt=1):
        super().__init__(dt=dt, print_log=True, save_log=False)
        self.bath = bath
        
    def _convert_input(self, **values):
        """Convert input from kwargs given to ramp().
        
        Normally, the kwargs key is in possible_inputs
        and at this stage the input has already been
        checked that it is indeed in possible_inputs
        """
        (temp_unit, temp_value), = values.items()
        if temp_unit == 'T':
            return temp_value
        else:
            return temp_value - 273.15
    
    def _apply_setting(self, value):
        self.bath.setpt = value
        
    def _read_setting(self):
        return self.bath.setpt
        
    def _print_setting(self, value):
        """Optional, but can be subclassed for better readability of setting info"""
        return f'Bath setting: T={value}°C'

# %% [markdown]
# # Simple operation of control object

# %%
bath = DummyCirculatedBath()
ctrl = BathControl(bath=bath)

# %%
ctrl.ramp('::5', T=(20, 25))
# Out:
# [2023-07-10 11:45:26] ==> NEW STEP from T=20 to T=25 in ::5
#
# [2023-07-10 11:45:26] Bath setting: T=20.0°C
# [2023-07-10 11:45:27] Bath setting: T=21.001°C
# [2023-07-10 11:45:28] Bath setting: T=22.005°C
# [2023-07-10 11:45:29] Bath setting: T=23.005°C
# [2023-07-10 11:45:30] Bath setting: T=24.005°C
# [2023-07-10 11:45:31] Bath setting: T=25°C

# %%
ctrl.ramp('::30', K=(283.15, 298.15))
# Out:
# [2023-07-10 11:45:33] ==> NEW STEP from K=283.15 to K=298.15 in ::30
#
# [2023-07-10 11:45:33] Bath setting: T=10.0°C
# [2023-07-10 11:45:34] Bath setting: T=10.501°C
# [2023-07-10 11:45:35] Bath setting: T=11.0°C
# [2023-07-10 11:45:36] Bath setting: T=11.503°C
# [2023-07-10 11:45:37] Bath setting: T=12.003°C
# [2023-07-10 11:45:38] Bath setting: T=12.501°C
# [2023-07-10 11:45:39] Bath setting: T=13.003°C
# [2023-07-10 11:45:40] Bath setting: T=13.503°C
# [2023-07-10 11:45:41] Bath setting: T=14.001°C
# [2023-07-10 11:45:42] Bath setting: T=14.502°C

# %%
ctrl.stop()
# Out:
# [2023-07-10 11:45:43] ==X Manual STOP

# %% [markdown]
# # Run Programs on Control object

# %%
prog = Stairs(control=ctrl, duration='::5', T=[25, 20, 15])
prog.plot()
# Out:
# /Users/olivier.vincent/Python-OV/prevo/prevo/control/program.py:202: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
prog.run()
# Out:
# [2023-07-10 11:45:46] ------ PROGRAM --- NEW CYCLE 1 / 1
#
# [2023-07-10 11:45:46] ==> NEW STEP from T=25 to T=25 in ::5
#
# [2023-07-10 11:45:46] Bath setting: T=25°C
# [2023-07-10 11:45:46] Dwelling started (T=25)
#
# [2023-07-10 11:45:51] Dwelling finished
#
# [2023-07-10 11:45:51] ==> NEW STEP from T=25 to T=20 in ::
#
# [2023-07-10 11:45:51] Bath setting: T=20°C
# [2023-07-10 11:45:51] ==> NEW STEP from T=20 to T=20 in ::5
#
# [2023-07-10 11:45:51] Bath setting: T=20°C
# [2023-07-10 11:45:51] Dwelling started (T=20)

# %%
prog.stop()
# Out:
# [2023-07-10 11:45:54] ==X Manual STOP
#
# [2023-07-10 11:45:54] ------ PROGRAM --- STOPPED

# %%
prog = Teeth(control=ctrl, slope=2, slope_unit='/s', plateau_duration="::4", T=[25, 20], repeat=2)
prog.plot()

# %% [raw]
# prog.run()

# %%
prog.run()
# Out:
# [2023-07-10 11:46:11] ------ PROGRAM --- NEW CYCLE 1 / 2
#
# [2023-07-10 11:46:11] ==> NEW STEP from T=25 to T=25 in ::4
#
# [2023-07-10 11:46:11] Bath setting: T=25°C
# [2023-07-10 11:46:11] Dwelling started (T=25)
#
# [2023-07-10 11:46:15] Dwelling finished
#
# [2023-07-10 11:46:15] ==> NEW STEP from T=25 to T=20 in 0:00:02.500000
#
# [2023-07-10 11:46:15] Bath setting: T=25.0°C
# [2023-07-10 11:46:16] Bath setting: T=22.994°C
# [2023-07-10 11:46:17] Bath setting: T=20.99°C
# [2023-07-10 11:46:18] Bath setting: T=20°C
# [2023-07-10 11:46:18] ==> NEW STEP from T=20 to T=20 in ::4
#
# [2023-07-10 11:46:18] Bath setting: T=20°C
# [2023-07-10 11:46:18] Dwelling started (T=20)

# %%
prog.stop()
# Out:
# [2023-07-10 11:46:20] ==X Manual STOP
#
# [2023-07-10 11:46:20] ------ PROGRAM --- STOPPED
